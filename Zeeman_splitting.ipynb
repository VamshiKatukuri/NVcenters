# %%
#pip install RISE
#pip install nbconvert

# %load_ext autoreload
# %autoreload 2
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython import display
from notebook_utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## A single NV center with nv-axis along the Z-axis

# %%
display.Image("../one_NVCenter_axis_small.png",width=400)

# %% [markdown]
# ## The NV defect levels within the band gap of diamond

# %%
display.Image("..//Energy_diagram.png",width=700)

# %% [markdown]
# # Zeeman splitting of single NV

# %%
z = interact(zeeman_split_single_NV,B=widgets.FloatSlider(min=0, max=0.02, step=0.001, value=0), lorentz_width=widgets.FloatSlider(min=0.05e6, max=200e6, step=1e6, value=.05e6))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='B', max=0.02, step=0.001), FloatSlider(value=50000.0…

# %% [markdown]
# # Hyperfine splitting

# %% [markdown]
# # 4 different NV axes

# %%
display.Image("../4_NVCenter_axis_1.png",width=800)

# %% [markdown]
# # Magnetic field B not aligned along any of the NV axes

# %%
y=interact(zeeman_split_NV_ensemble_B_random,B=widgets.FloatSlider(min=0, max=0.02, step=0.001, value=0), lorentz_width=widgets.FloatSlider(min=1e6, max=200e6, step=1e6, value=0.5e6))
# Out:
# interactive(children=(FloatSlider(value=0.0, description='B', max=0.02, step=0.001), FloatSlider(value=1000000…

# %% [markdown]
# # Magnetic field B aligned along one of the NV axes

# %%
x = interact(zeeman_split_NV_ensemble,B=widgets.FloatSlider(min=1e-6, max=2e-2, step=0.001, value=0), lorentz_width=widgets.FloatSlider(min=1e6, max=100e6, step=1e6, value=30e6))
# Out:
# interactive(children=(FloatSlider(value=1e-06, description='B', max=0.02, min=1e-06, step=0.001), FloatSlider(…
